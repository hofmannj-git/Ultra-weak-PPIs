# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.colors as colors
from scipy import stats
from scipy.optimize import curve_fit

# %matplotlib inline

def nmtosigma(r):
    return -0.0456*r**4 + 0.2975*r**3 - 0.8392*r**2 + 0.2821*r + 0.942

Kd_plot = np.loadtxt('../FIG2B_S3D_S4A__Kd_vs_V0kT.txt')
epsilon = [0, 0.5, 1, 1.5, 2, 2.5, 3, 4, 5, 6]

fig, ax = plt.subplots()

plt.plot(epsilon,Kd_plot[:,0],color='k',marker='s',markersize=8,linewidth=3.5,zorder=3)

ax.set_yscale('log')
ax.set_ylim(1e-7,1e1)
ax.set_xlabel('Attraction strength, $V_0/k_BT$',size=22)
ax.set_ylabel('$K_{d,app}$, [M]',size=22)

for ax in [ax]:
    ax.spines['left'].set_linewidth(4)
    ax.spines['bottom'].set_linewidth(4)
    ax.spines['top'].set_linewidth(4)
    ax.spines['right'].set_linewidth(4)
    ax.tick_params(axis='both', labelsize=22,width=3,length=10)

t = ax.yaxis.get_offset_text()
t.set_size(15)
t = ax.xaxis.get_offset_text()
t.set_size(15)
axa = ax.twiny()
axa.set_xlim(ax.get_xlim())
new_tick_locations = np.array([0.0, 1.78, 3.04, 5.00]) # SEE B2 CALCULATION
axa.set_xticks(new_tick_locations)
axa.set_xticklabels([1.0, 0.0, -1.5, -10])
axa.tick_params(labelsize=0,width=3,length=8)
axa.set_xlabel('Reduced second virial coefficient, $B_2^*$',size=20, labelpad=12)
axa.tick_params(labelsize=20)

fig.set_size_inches(10, 7)
plt.savefig('./images/Kd_app.png', bbox_inches='tight', dpi=300)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.colors as colors
from scipy import stats
from scipy.optimize import curve_fit

# %matplotlib inline

Kd_plot = np.loadtxt('../FIG2B_S3D_S4A__Kd_vs_V0kT.txt')
epsilon = [0, 0.5, 1, 1.5, 2, 2.5, 3, 4, 5, 6]

fig, ax = plt.subplots()

plt.plot(epsilon,Kd_plot[:,0],color='k',marker='s',markersize=8,linewidth=3.5,zorder=3)

Kd_cluster = [0.02117394610544165, 0.015597229465231044, 0.010470161301510175, 0.007414624893451698, 0.004563274682996947, 0.0021523841870583083]
eps_cluster = [0, 0.5, 1, 1.5, 2, 2.5]
plt.plot(eps_cluster,Kd_cluster,color='forestgreen',marker='o',markersize=8,linestyle='--',linewidth=3.5,zorder=3)

ax.set_yscale('log')
ax.set_ylim(1e-7,1e1)
ax.set_xlabel('Electrostatic attraction strength, $V_0/k_BT$',size=22)
ax.set_ylabel('$K_{d,app}$ [M]',size=22)

for ax in [ax]:
    ax.spines['left'].set_linewidth(4)
    ax.spines['bottom'].set_linewidth(4)
    ax.spines['top'].set_linewidth(4)
    ax.spines['right'].set_linewidth(4)
    ax.tick_params(axis='both', labelsize=20,width=3,length=10)
    ax.tick_params(which='minor', length=6,width=2)
    
fig.set_size_inches(10, 7)
plt.savefig('./images/Kd_app_cluster.png', bbox_inches='tight', dpi=300)

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.colors as colors
from scipy import stats
from scipy.optimize import curve_fit

# %matplotlib inline

def nmtosigma(r):
    return -0.0456*r**4 + 0.2975*r**3 - 0.8392*r**2 + 0.2821*r + 0.942

Kd_plot = np.loadtxt('../FIG2B_S3D_S4A__Kd_vs_V0kT.txt')
epsilon = [0, 0.5, 1, 1.5, 2, 2.5, 3, 4, 5, 6]

fig, ax = plt.subplots()

plt.plot(epsilon,Kd_plot[:,0],color='k',marker='s',markersize=8,linewidth=3.5,zorder=3)
plt.plot(epsilon,Kd_plot[:,1],color='grey',marker='s',markersize=7,linewidth=3,zorder=3)
plt.plot(epsilon,Kd_plot[:,2],color='lightgrey',marker='s',markersize=7,linewidth=3,zorder=3)

ax.set_yscale('log')
ax.set_ylim(1e-7,1e1)
ax.set_xlabel('Attraction strength, $V_0/k_BT$',size=22)
ax.set_ylabel('$K_{d,app}$, [M]',size=22)

for ax in [ax]:
    ax.spines['left'].set_linewidth(4)
    ax.spines['bottom'].set_linewidth(4)
    ax.spines['top'].set_linewidth(4)
    ax.spines['right'].set_linewidth(4)
    ax.tick_params(axis='both', labelsize=22,width=3,length=10)

t = ax.yaxis.get_offset_text()
t.set_size(15)
t = ax.xaxis.get_offset_text()
t.set_size(15)
axa = ax.twiny()
axa.set_xlim(ax.get_xlim())
new_tick_locations = np.array([0.0, 1.78, 3.04, 5.00])
axa.set_xticks(new_tick_locations)
axa.set_xticklabels([1.0, 0.0, -1.5, -10])
axa.tick_params(labelsize=0,width=3,length=8)
axa.set_xlabel('Reduced second virial coefficient, $B_2^*$',size=20, labelpad=12)
axa.tick_params(labelsize=20)

fig.set_size_inches(10, 7)
plt.savefig('./images/Kd_app_SA.png', bbox_inches='tight', dpi=300)
